# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
x = [1,2,3,4,5]
y = [2,6,9,11,13]

#Crea el plot -- acepta listas o una serie
plt.plot(x,y)

#Nombrar ejes
plt.xlabel('Eje X')
plt.ylabel('Eje y')

#Nombre grafico
plt.title('Grafico de linea')

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.bar(df_fact['movieID'], df_fact['rating'])
#       2 plt.show()
#
# NameError: name 'df_fact' is not defined
