# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine("mysql://root:root@172.16.5.4:3310/db_movies_netflix_transact")
conn = engine.connect()

# %% [markdown]
# # Cargamos datos a la dimension Movie

# %%
query = """
SELECT 
    movie.movieID as movieID, movie.movieTitle as title, movie.releaseDate as releaseDate, 
    gender.name as gender , person.name as participantName, participant.participantRole as roleparticipant 
FROM movie 
INNER JOIN participant 
ON movie.movieID=participant.movieID
INNER JOIN person
ON person.personID = participant.personID
INNER JOIN movie_gender 
ON movie.movieID = movie_gender.movieID
INNER JOIN gender 
ON movie_gender.genderID = gender.genderID
"""

# %%
movies_data=pd.read_sql(query, con=conn) 
movies_data["movieID"]=movies_data["movieID"].astype('int')
movies_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant
# 0           Actor
# 1           Actor
# 2        Director

# %%
movies_award=pd.read_csv("./data/Awards_movie.csv")
movies_award["movieID"]=movies_award["movieID"].astype('int')
movies_award.rename(columns={"Aware":"Award"}, inplace=True) #In place=True hace la transformacio sobre el dataframe
movies_award
# Out:
#     movieID  IdAward   Award
# 0  80210920        0   Oscar
# 1  81157374        1  Grammy
# 2  80192187        2   Oscar

# %%
movie_data=pd.merge(movies_data,movies_award, left_on="movieID", right_on="movieID")
movie_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant  IdAward   Award
# 0           Actor        2   Oscar
# 1           Actor        0   Oscar
# 2        Director        1  Grammy

# %%
engine = db.create_engine("mysql://root:root@172.16.5.4:3310/dw_netflix")
conn = engine.connect()

# %%
movie_data = movie_data.rename(columns={'releaseDate': 'releaseMovie', 'Award': 'awardMovie'})

# %%
movie_data = movie_data.drop(columns=['IdAward'])

# %%
movie_data.to_sql('dimMovie',conn,if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 movie_data.to_sql('dimMovie',conn,if_exists='append', index=False)
#
# NameError: name 'movie_data' is not defined

# %% [markdown]
# # Cargamos datos a la dimension USER

# %%
users = pd.read_csv("./data/users.csv", sep='|')
users
# Out:
#       idUser     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users = users.rename(columns={'idUser': 'userID'})
users
# Out:
#       userID     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users.to_sql('dimUser',conn,if_exists='append', index=False)
# Out:
# 20

# %% [markdown]
# # Cargamos datos a la tabla de hechos

# %%
users_id=users["userID"]
movies_id=movies_data["movieID"]

# %%
watchs_data=pd.merge(users_id,movies_id, how="cross")
watchs_data
# Out:
#       userID   movieID
# 0    1002331  80192187
# 1    1002331  80210920
# 2    1002331  81157374
# 3    1002332  80192187
# 4    1002332  80210920
# 5    1002332  81157374
# 6    1002333  80192187
# 7    1002333  80210920
# 8    1002333  81157374
# 9    1002334  80192187
# 10   1002334  80210920
# 11   1002334  81157374
# 12   1002335  80192187
# 13   1002335  80210920
# 14   1002335  81157374
# 15   1002336  80192187
# 16   1002336  80210920
# 17   1002336  81157374
# 18   1002337  80192187
# 19   1002337  80210920
# 20   1002337  81157374
# 21   1002338  80192187
# 22   1002338  80210920
# 23   1002338  81157374
# 24   1002339  80192187
# 25   1002339  80210920
# 26   1002339  81157374
# 27  10023310  80192187
# 28  10023310  80210920
# 29  10023310  81157374
# 30  10023311  80192187
# 31  10023311  80210920
# 32  10023311  81157374
# 33  10023312  80192187
# 34  10023312  80210920
# 35  10023312  81157374
# 36  10023313  80192187
# 37  10023313  80210920
# 38  10023313  81157374
# 39  10023314  80192187
# 40  10023314  80210920
# 41  10023314  81157374
# 42  10023315  80192187
# 43  10023315  80210920
# 44  10023315  81157374
# 45  10023316  80192187
# 46  10023316  80210920
# 47  10023316  81157374
# 48  10023317  80192187
# 49  10023317  80210920
# 50  10023317  81157374
# 51  10023318  80192187
# 52  10023318  80210920
# 53  10023318  81157374
# 54  10023319  80192187
# 55  10023319  80210920
# 56  10023319  81157374
# 57  10023320  80192187
# 58  10023320  80210920
# 59  10023320  81157374

# %%
import random
from datetime import datetime, timedelta
import random

def gen_rating():
    # Generar un número aleatorio entre 0 y 5 con 1 solo decimal
    numero_aleatorio = round(random.uniform(0, 5), 1)
    # Mostrar el número aleatorio
    return numero_aleatorio

def gen_timestamp():
    # Generar un timestamp aleatorio dentro de un rango específico
    start_date = datetime(2024, 1, 15)
    end_date = datetime(2024, 4, 6)

    # Calcular un valor aleatorio entre start_date y end_date
    random_date = start_date + timedelta(seconds=random.randint(0, int((end_date - start_date).total_seconds())))

    # Mostrar el timestamp aleatorio
    return random_date

# %%
watchs_data["rating"]=watchs_data["movieID"].apply(lambda x: gen_rating())
watchs_data["timestamp"]=watchs_data["userID"].apply(lambda x: gen_timestamp())

# %%
watchs_data
# Out:
#       userID   movieID  rating           timestamp
# 0    1002331  80192187     0.5 2024-02-06 18:28:32
# 1    1002331  80210920     0.5 2024-02-13 16:47:41
# 2    1002331  81157374     4.6 2024-01-31 02:03:48
# 3    1002332  80192187     1.4 2024-03-21 22:26:42
# 4    1002332  80210920     0.5 2024-03-29 18:04:49
# 5    1002332  81157374     1.4 2024-03-10 00:38:58
# 6    1002333  80192187     3.4 2024-01-28 14:30:16
# 7    1002333  80210920     2.1 2024-01-17 04:16:29
# 8    1002333  81157374     2.5 2024-02-28 17:37:20
# 9    1002334  80192187     4.7 2024-03-23 19:43:13
# 10   1002334  80210920     0.6 2024-02-20 10:15:52
# 11   1002334  81157374     1.5 2024-04-02 01:24:54
# 12   1002335  80192187     1.3 2024-02-01 21:56:07
# 13   1002335  80210920     1.6 2024-02-27 01:41:16
# 14   1002335  81157374     1.8 2024-03-06 20:05:28
# 15   1002336  80192187     2.8 2024-03-01 10:57:48
# 16   1002336  80210920     0.7 2024-04-04 15:36:04
# 17   1002336  81157374     3.9 2024-02-05 07:59:13
# 18   1002337  80192187     1.4 2024-03-28 08:27:11
# 19   1002337  80210920     4.4 2024-03-11 14:57:21
# 20   1002337  81157374     4.7 2024-03-28 14:25:40
# 21   1002338  80192187     4.2 2024-02-15 06:38:59
# 22   1002338  80210920     2.3 2024-02-18 08:34:03
# 23   1002338  81157374     1.7 2024-02-06 23:23:18
# 24   1002339  80192187     3.5 2024-01-31 19:09:58
# 25   1002339  80210920     1.7 2024-03-21 10:46:40
# 26   1002339  81157374     0.8 2024-02-08 22:03:23
# 27  10023310  80192187     4.9 2024-02-17 18:31:16
# 28  10023310  80210920     4.3 2024-03-29 16:20:53
# 29  10023310  81157374     2.1 2024-03-13 22:09:58
# 30  10023311  80192187     4.9 2024-01-25 19:25:05
# 31  10023311  80210920     0.8 2024-03-16 19:11:35
# 32  10023311  81157374     1.0 2024-03-05 17:31:07
# 33  10023312  80192187     4.0 2024-04-05 16:03:32
# 34  10023312  80210920     0.2 2024-02-16 12:51:14
# 35  10023312  81157374     1.6 2024-02-11 08:30:41
# 36  10023313  80192187     4.7 2024-02-01 16:34:35
# 37  10023313  80210920     1.9 2024-03-30 16:15:10
# 38  10023313  81157374     3.8 2024-03-13 13:05:26
# 39  10023314  80192187     1.6 2024-03-25 00:38:05
# 40  10023314  80210920     3.6 2024-01-25 20:36:52
# 41  10023314  81157374     1.3 2024-02-21 18:35:08
# 42  10023315  80192187     1.7 2024-03-17 18:45:17
# 43  10023315  80210920     4.4 2024-03-07 12:18:11
# 44  10023315  81157374     2.3 2024-02-10 20:17:56
# 45  10023316  80192187     4.3 2024-04-01 17:25:41
# 46  10023316  80210920     0.8 2024-03-10 21:38:30
# 47  10023316  81157374     3.0 2024-02-01 04:23:22
# 48  10023317  80192187     2.1 2024-03-26 04:57:52
# 49  10023317  80210920     0.9 2024-02-27 23:03:37
# 50  10023317  81157374     1.6 2024-02-03 17:10:59
# 51  10023318  80192187     0.2 2024-02-28 23:03:44
# 52  10023318  80210920     5.0 2024-03-08 16:37:50
# 53  10023318  81157374     2.4 2024-02-02 02:28:55
# 54  10023319  80192187     2.5 2024-03-03 06:48:53
# 55  10023319  80210920     2.1 2024-03-30 20:22:56
# 56  10023319  81157374     4.6 2024-01-28 00:06:39
# 57  10023320  80192187     2.3 2024-03-31 21:13:20
# 58  10023320  80210920     0.8 2024-03-30 07:35:56
# 59  10023320  81157374     1.1 2024-02-05 03:06:06

# %%
# Cargamos tabla de hechos
watchs_data.to_sql("FactWatchs", conn, if_exists='append', index=False)
# Out:
# 60

# %%
### SET FOREIGN_KEY_CHECKS = 0;
### SET FOREIGN_KEY_CHECKS = 1;
